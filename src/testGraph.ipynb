# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from pyvis.network import Network

# %%
# Compute Euclidean distance between two samples
def euclidean_distance(sample1, sample2):
    return np.linalg.norm(sample1 - sample2)


def compute_distance(df, index1, index2):
    sample1 = df.iloc[index1].values
    sample2 = df.iloc[index2].values
    return euclidean_distance(sample1, sample2)

# %%
# Create a dummy DataFrame with 10 samples
data = {
    'Feature 1': [0, 1, 2, 3, 100],
}

df = pd.DataFrame(data)
# Compute similarity matrix
similarity_matrix = np.zeros((df.shape[0], df.shape[0]))

for i in range(df.shape[0]):
    for j in range(df.shape[0]):
        if i != j:  # Exclude self-edges
            distance = compute_distance(df, i, j)
            similarity_matrix[i, j] = 1 / (1 + distance)

# Compute average similarity and standard deviation
average_similarity = np.mean(similarity_matrix)
std_similarity = np.std(similarity_matrix)

print("Average Similarity:", average_similarity)
print("Standard Deviation of Similarity:", std_similarity)

# Apply threshold on similarity matrix
threshold = 100  # Adjust the threshold as needed
similarity_matrix[similarity_matrix < threshold] = 0

# Create graph from similarity matrix
G = nx.from_numpy_matrix(similarity_matrix)

# Plot the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=500, font_size=10, edge_color='gray')
plt.title("Similarity Graph")
plt.show()
# Out:
# Average Similarity: 0.19654981987994716
# Standard Deviation of Similarity: 0.21018630009183636

# %%
# Create a dummy DataFrame with 10 samples
data = {
    'Feature 1': [50, 51, 52, 53, 55, 65, 85, 86, 87, 88],
}

df = pd.DataFrame(data)
# Compute similarity matrix
similarity_matrix = np.zeros((df.shape[0], df.shape[0]))

for i in range(df.shape[0]):
    for j in range(df.shape[0]):
        if i != j:  # Exclude self-edges
            distance = compute_distance(df, i, j)
            similarity_matrix[i, j] = 1 / (1 + distance)

# Compute average similarity and standard deviation
average_similarity = np.mean(similarity_matrix)
std_similarity = np.std(similarity_matrix)

print("Average Similarity:", average_similarity)
print("Standard Deviation of Similarity:", std_similarity)

# Apply threshold on similarity matrix
threshold = average_similarity  # Adjust the threshold as needed
similarity_matrix[similarity_matrix < threshold] = 0

# Create graph from similarity matrix
G = nx.from_numpy_matrix(similarity_matrix)

# Plot the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=500, font_size=10, edge_color='gray')
plt.title("Similarity Graph")
plt.show()


# Create a pyvis network
nt = Network(notebook=True)

# Add nodes and edges to the network
for node in G.nodes():
    nt.add_node(node)

for edge in G.edges():
    nt.add_edge(edge[0], edge[1])

# # Display the network
# nt.show("graphAllSimilar.html")
# Out:
# Average Similarity: 0.13797015523210546
# Standard Deviation of Similarity: 0.16797962947901532
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
print(similarity_matrix)
# Out:
# [[0.         0.09090909 0.03225806]
#  [0.09090909 0.         0.04761905]
#  [0.03225806 0.04761905 0.        ]]

# %%
# Create a dummy DataFrame with 10 samples
data = {
    'Feature 1': [0, 1, 2, 3, 4, 5],
}

df = pd.DataFrame(data)
# Compute similarity matrix
similarity_matrix = np.zeros((df.shape[0], df.shape[0]))

for i in range(df.shape[0]):
    for j in range(df.shape[0]):
        if i != j:  # Exclude self-edges
            distance = compute_distance(df, i, j)
            similarity_matrix[i, j] = 1 / (1 + distance)

# Compute average similarity and standard deviation
average_similarity = np.mean(similarity_matrix)
std_similarity = np.std(similarity_matrix)

print("Average Similarity:", average_similarity)
print("Standard Deviation of Similarity:", std_similarity)

# Apply threshold on similarity matrix
# threshold = 0.16  # Adjust the threshold as needed
# similarity_matrix[similarity_matrix < threshold] = 0

# Create graph from similarity matrix
G = nx.from_numpy_matrix(similarity_matrix)

# Plot the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=500, font_size=10, edge_color='gray')
plt.title("Similarity Graph")
plt.show()


# Create a pyvis network
nt = Network(notebook=True)

# Add nodes and edges to the network
for node in G.nodes():
    nt.add_node(node)

for edge in G.edges():
    nt.add_edge(edge[0], edge[1])

# # Display the network
# nt.show("graphAllSimilar.html")
# Out:
# Average Similarity: 0.28611111111111115
# Standard Deviation of Similarity: 0.1693533452741798
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
# Create a dummy DataFrame with 10 samples
data = {
    'Feature 1': [0, 1, 2, 3, 4, 5],
}

df = pd.DataFrame(data)
# Compute similarity matrix
similarity_matrix = np.zeros((df.shape[0], df.shape[0]))

for i in range(df.shape[0]):
    for j in range(df.shape[0]):
        if i != j:  # Exclude self-edges
            distance = compute_distance(df, i, j)
            similarity_matrix[i, j] = 1 / (1 + distance)

# Compute average similarity and standard deviation
average_similarity = np.mean(similarity_matrix)
std_similarity = np.std(similarity_matrix)

print("Average Similarity:", average_similarity)
print("Standard Deviation of Similarity:", std_similarity)

# Apply threshold on similarity matrix
# threshold = 0.16  # Adjust the threshold as needed
# similarity_matrix[similarity_matrix < threshold] = 0

# Create graph from similarity matrix

G = nx.from_numpy_matrix(similarity_matrix)

# Plot the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=500, font_size=10, edge_color='gray')
plt.title("Similarity Graph")
plt.show()


# Create a pyvis network
nt = Network(notebook=True)

# Add nodes and edges to the network
for node in G.nodes():
    nt.add_node(node)

for edge in G.edges():
    nt.add_edge(edge[0], edge[1])

# # Display the network
# nt.show("graphAllSimilar.html")
# Out:
# Average Similarity: 0.28611111111111115
# Standard Deviation of Similarity: 0.1693533452741798
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
data_f = pd.DataFrame({
    'Feature 1': [0, 1, 2, 3, 4, 5],
})

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# Assuming your data_fset is stored in a data_fFrame called 'df'
# Assuming the filtered data_fset with the "ICU" feature is stored in a data_fFrame called 'filtered_df'
# Assuming the correlations are stored in a dictionary called 'correlations_dict'

# Compute weighted distance between two samples in the data_fFrame
def compute_distance(df, index1, index2):
    sample1 = df.iloc[index1].values
    sample2 = df.iloc[index2].values
    weighted_distance = 0
    
    for i in range(len(sample1)):
        weighted_distance += abs(sample1[i] - sample2[i])
    
    return weighted_distance

# Step 1: Find pairwise weighted distances
dist_matrix = np.zeros((data_f.shape[0], data_f.shape[0]))

for i in range(data_f.shape[0]):
    for j in range(i + 1, data_f.shape[0]):
        weighted_dist = compute_distance(data_f, i, j)
        dist_matrix[i, j] = weighted_dist
        dist_matrix[j, i] = weighted_dist

# Check distances set to 0 outside diagonal
# for i in range(dist_matrix.shape[0]):
#     for j in range(dist_matrix.shape[1]):
#         if i != j and dist_matrix[i, j] == 0:
#             print(f"Distance between points {i} and {j} is set to 0.")


# Step 2: Find k nearest neighbors for each sample
k = 5  # Number of nearest neighbors
n_neighbors = []

for i in range(dist_matrix.shape[0]):
    neighbors = np.argsort(dist_matrix[i])
    
    # Find neighbors with distance equal to 0
    zero_distance_neighbors = [neighbor for neighbor in neighbors if dist_matrix[i, neighbor] == 0]
    
    # Find additional nearest neighbors with distance > 0
    additional_neighbors = [neighbor for neighbor in neighbors if dist_matrix[i, neighbor] > 0][:k]
    
    neighbors_list = zero_distance_neighbors + additional_neighbors
    n_neighbors.append(neighbors_list)

# nearest_neighbors = np.argsort(dist_matrix, axis=1)[:, 1:(k+1)]


# print(nearest_neighbors)

# Step 3: Create graph and add edges
graph = nx.Graph()
for i, neighbors in enumerate(n_neighbors):
    for neighbor in neighbors:
        if (i != neighbor) :
            graph.add_edge(i, neighbor)

# Step 5: Plot the graph
plt.figure(figsize=(8, 8))
pos = nx.spring_layout(graph)
nx.draw(graph, pos, with_labels=True, node_size=500, font_size=10, edge_color='gray')
plt.axis("off")
plt.show()
